# %% [markdown]
# # Credit fraud prediciton using Machine Learning

# %% [markdown]
# ![images.jpeg](attachment:images.jpeg)

# %% [markdown]
# Author :  __LAGRE GABBA BERTRAND__

# %% [markdown]
# ## 1. Data reading

# %%
# we import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier,RandomForestClassifier
import xgboost as xgb
import joblib,pickle 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("creditcard.csv")
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
df.dtypes.to_list()
# Out:
# [dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64')]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## 2. Data Visualization

# %%
df.hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
columns = df.columns.tolist()
len(columns)
# Out:
# 31

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %%
# Out:
# "plt.figure(figsize=(16,38))\n\nfor i, col in enumerate(columns,2):\n    plt.subplot(8,4,i)\n    sns.kdeplot(df[col], color = '#d1aa00', fill = True)\n    plt.subplot(8,4,i+11)\n    df[col].plot.box()\nplt.tight_layout()\nplt.show()\n"

# %%
pd.DataFrame(data=[df[columns].skew(),df[columns].kurtosis()],index=['skewness','kurtosis'])
# Out:
#               Time         V1         V2         V3        V4          V5  \
# skewness -0.035568  -3.280667  -4.624866  -2.240155  0.676292   -2.425901
# kurtosis -1.293530  32.486679  95.773106  26.619551  2.635455  206.904560
#
#                  V6          V7          V8        V9  ...         V21  \
# skewness   1.826581    2.553907   -8.521944  0.554680  ...    3.592991
# kurtosis  42.642494  405.607417  220.586974  3.731311  ...  207.287040
#
#                V22         V23       V24       V25       V26         V27  \
# skewness -0.213258   -5.875140 -0.552499 -0.415793  0.576693   -1.170209
# kurtosis  2.832967  440.088659  0.618871  4.290412  0.919006  244.989241
#
#                  V28      Amount       Class
# skewness   11.192091   16.977724   23.997579
# kurtosis  933.397502  845.092646  573.887843
#
# [2 rows x 31 columns]

# %% [markdown]
# there are outlier that we want to remove.

# %%
for col in columns[0:30]:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]

# %%
pd.DataFrame(data=[df[columns[0:30]].skew(),df[columns[0:30]].kurtosis()],index=['skewness','kurtosis'])
# Out:
#               Time        V1        V2        V3        V4        V5  \
# skewness  0.066902 -0.594042 -0.028066 -0.231616 -0.064477 -0.020789
# kurtosis -1.360156 -0.958648 -0.232231 -0.558729  0.295200  0.071531
#
#                 V6        V7        V8        V9  ...      V20       V21  \
# skewness  0.467910 -0.179074  0.486434 -0.064214  ...  0.21638  0.183806
# kurtosis  0.271169 -0.051440  0.251346  0.270628  ...  0.45325 -0.427473
#
#               V22       V23       V24       V25       V26       V27       V28  \
# skewness  0.14637  0.060714 -0.505516 -0.105162  0.223430  0.687808  0.227985
# kurtosis -0.69475 -0.177386  0.036364 -0.582135 -0.128106  0.747688 -0.018837
#
#             Amount
# skewness  1.417848
# kurtosis  1.198263
#
# [2 rows x 30 columns]

# %%
f = plt.figure(figsize=(22,22))
sns.set()
sns.heatmap(df.corr(), linewidths='2',annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#  create a column that interpret each value of target
def credit_class(Class):
    if (Class ==1):
        return "Yes"
    else:
        return "No"

df['Interpretation'] = df['Class'].apply(credit_class)
df.head()
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
#
#           V7        V8        V9  ...       V22       V23       V24       V25  \
# 1  -0.078803  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170
# 5   0.476201  0.260314 -0.568671  ... -0.559825 -0.026398 -0.371427 -0.232794
# 6  -0.005159  0.081213  0.464960  ... -0.270710 -0.154104 -0.780055  0.750137
# 9   0.651583  0.069539 -0.736727  ... -0.633753 -0.120794 -0.385050 -0.069733
# 12 -0.689405 -0.227487 -2.094011  ... -0.483285  0.084668  0.392831  0.161135
#
#          V26       V27       V28  Amount  Class  Interpretation
# 1   0.125895 -0.008983  0.014724    2.69      0              No
# 5   0.105915  0.253844  0.081080    3.67      0              No
# 6  -0.257237  0.034507  0.005168    4.99      0              No
# 9   0.094199  0.246219  0.083076    3.68      0              No
# 12 -0.354990  0.026416  0.042422  121.50      0              No
#
# [5 rows x 32 columns]

# %%
df['Interpretation'].value_counts()
# Out:
# No     110109
# Yes        13
# Name: Interpretation, dtype: int64

# %%
for col in columns:
    sns.kdeplot(df.loc[df['Interpretation']=='Yes',col], label='Yes')
    sns.kdeplot(df.loc[df['Interpretation']=='No',col], label='No')
    plt.legend()
    plt.show()
    
    print(f"Relation between {col} and Interpretation")
# Out:
# Relation between Time and Interpretation
# Relation between V1 and Interpretation
# Relation between V2 and Interpretation
# Relation between V3 and Interpretation
# Relation between V4 and Interpretation
# Relation between V5 and Interpretation
# Relation between V6 and Interpretation
# Relation between V7 and Interpretation
# Relation between V8 and Interpretation
# Relation between V9 and Interpretation
# Relation between V10 and Interpretation
# Relation between V11 and Interpretation
# Relation between V12 and Interpretation
# Relation between V13 and Interpretation
# Relation between V14 and Interpretation
# Relation between V15 and Interpretation
# Relation between V16 and Interpretation
# Relation between V17 and Interpretation
# Relation between V18 and Interpretation
# Relation between V19 and Interpretation
# Relation between V20 and Interpretation
# Relation between V21 and Interpretation
# Relation between V22 and Interpretation
# Relation between V23 and Interpretation
# Relation between V24 and Interpretation
# Relation between V25 and Interpretation
# Relation between V26 and Interpretation
# Relation between V27 and Interpretation
# Relation between V28 and Interpretation
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Relation between Amount and Interpretation
# Relation between Class and Interpretation

# %%
df.isnull().sum()
# Out:
# Time              0
# V1                0
# V2                0
# V3                0
# V4                0
# V5                0
# V6                0
# V7                0
# V8                0
# V9                0
# V10               0
# V11               0
# V12               0
# V13               0
# V14               0
# V15               0
# V16               0
# V17               0
# V18               0
# V19               0
# V20               0
# V21               0
# V22               0
# V23               0
# V24               0
# V25               0
# V26               0
# V27               0
# V28               0
# Amount            0
# Class             0
# Interpretation    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Time              0
# V1                0
# V2                0
# V3                0
# V4                0
# V5                0
# V6                0
# V7                0
# V8                0
# V9                0
# V10               0
# V11               0
# V12               0
# V13               0
# V14               0
# V15               0
# V16               0
# V17               0
# V18               0
# V19               0
# V20               0
# V21               0
# V22               0
# V23               0
# V24               0
# V25               0
# V26               0
# V27               0
# V28               0
# Amount            0
# Class             0
# Interpretation    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 1         False
# 5         False
# 6         False
# 9         False
# 12        False
#           ...
# 284794    False
# 284796    False
# 284797    False
# 284800    False
# 284801    False
# Length: 110122, dtype: bool

# %%
df.shape
# Out:
# (110122, 32)

# %% [markdown]
# ## 3. Model training

# %%
X = df.drop(['Class','Interpretation'],axis=1)
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 5            2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6            4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 9            9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 12          10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...          ...       ...       ...       ...       ...       ...       ...
# 284794  172777.0 -1.266580 -0.400461  0.956221 -0.723919  1.531993 -1.788600
# 284796  172780.0  1.884849 -0.143540 -0.999943  1.506772 -0.035300 -0.613638
# 284797  172782.0 -0.241923  0.712247  0.399806 -0.463406  0.244531 -1.343668
# 284800  172784.0  2.039560 -0.175233 -1.196825  0.234580 -0.008713 -0.726571
# 284801  172785.0  0.120316  0.931005 -0.546012 -0.745097  1.130314 -0.235973
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 1      -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672
# 5       0.476201  0.260314 -0.568671  ...  0.084968 -0.208254 -0.559825
# 6      -0.005159  0.081213  0.464960  ... -0.219633 -0.167716 -0.270710
# 9       0.651583  0.069539 -0.736727  ...  0.203711 -0.246914 -0.633753
# 12     -0.689405 -0.227487 -2.094011  ... -0.102756 -0.231809 -0.483285
# ...          ...       ...       ...  ...       ...       ...       ...
# 284794  0.314741  0.004704  0.013857  ... -0.029539 -0.157831 -0.883365
# 284796  0.190241 -0.249058  0.666458  ... -0.153997  0.144008  0.634646
# 284797  0.929369 -0.206210  0.106234  ... -0.139512 -0.228876 -0.514376
# 284800  0.017050 -0.118228  0.435402  ... -0.256922 -0.268048 -0.717211
# 284801  0.812722  0.115093 -0.204064  ...  0.000676 -0.314205 -0.808520
#
#              V23       V24       V25       V26       V27       V28  Amount
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 5      -0.026398 -0.371427 -0.232794  0.105915  0.253844  0.081080    3.67
# 6      -0.154104 -0.780055  0.750137 -0.257237  0.034507  0.005168    4.99
# 9      -0.120794 -0.385050 -0.069733  0.094199  0.246219  0.083076    3.68
# 12      0.084668  0.392831  0.161135 -0.354990  0.026416  0.042422  121.50
# ...          ...       ...       ...       ...       ...       ...     ...
# 284794  0.088485 -0.076790 -0.095833  0.132720 -0.028468  0.126494    0.89
# 284796 -0.042114 -0.053206  0.316403 -0.461441  0.018265 -0.041068   60.00
# 284797  0.279598  0.371441 -0.559238  0.113144  0.131507  0.081265    5.49
# 284800  0.297930 -0.359769 -0.315610  0.201114 -0.080826 -0.075071    2.68
# 284801  0.050343  0.102800 -0.435870  0.124079  0.217940  0.068803    2.69
#
# [110122 rows x 30 columns]

# %% [markdown]
# Our target y will be the column Class.

# %%
Y = df['Class']

# %%
# we can use the chi2 to select the best features
selector = SelectKBest(chi2)
x_chi2 = selector.fit_transform(np.abs(X),Y)
selected_feature_indices = selector.get_support(indices=True)
selected_feature_indices

# print what features are selected
for i in selected_feature_indices:
    print(columns[i])
# Out:
# Time
# V1
# V3
# V4
# V10
# V11
# V14
# V15
# V17
# V19

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_chi2, Y, test_size = 0.3, train_size=0.7,random_state=42)

# %%
labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Now it's time the test algorimths and we can choose the best

# %% [markdown]
# ## 3. 1. Gaussian

# %%
gauss = GaussianNB()
gauss.fit(X_train, Y_train)
Y_pred = gauss.predict(X_test)

# %%
gauss_accuracy = round(accuracy_score(Y_test,Y_pred)*100,2)
print(f"the accuracy is {gauss_accuracy} %")
# Out:
# the accuracy is 99.97 %

# %%
predictions = gauss.predict(X_test)
print(f"The error is {round(mean_squared_error(predictions, Y_test)*100,2)} %")
# Out:
# The error is 0.03 %

# %% [markdown]
# ## 3.2. kneighbor

# %%
kneighbor = KNeighborsClassifier(n_neighbors = 4)
kneighbor.fit(X_train, Y_train)
Y_pred = kneighbor.predict(X_test)

# %%
kneighbor_accuracy = round(accuracy_score(Y_test,Y_pred)*100,2)
print(f"the accuracy is {kneighbor_accuracy} %")
# Out:
# the accuracy is 99.99 %

# %%
predictions = kneighbor.predict(X_test)
print(f"The error is {round(mean_squared_error(predictions, Y_test)*100,2)} %")
# Out:
# The error is 0.01 %

# %% [markdown]
# ##  3.3 Random Forest Classifier algorithm

# %%
random_fr = RandomForestClassifier(n_estimators=100,random_state=42)
random_fr.fit(X_train, Y_train)
Y_pred = random_fr.predict(X_test)

# %%
random_accuracy = round(accuracy_score(Y_test,Y_pred)*100,2)
print(f"the accuracy is {random_accuracy} %")
# Out:
# the accuracy is 99.99 %

# %%
predictions = random_fr.predict(X_test)
print(f"The error is {round(mean_squared_error(predictions, Y_test)*100,2)} %")
# Out:
# The error is 0.01 %

# %%
import matplotlib.pyplot as plt

models = ['random forest',  'K neighbours','Guassian']
scores = [random_accuracy ,kneighbor_accuracy,gauss_accuracy]


plt.figure(figsize=(12, 8))
plt.bar(models, scores, color='green')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model accuracy')

plt.show()

# %%
import matplotlib.pyplot as plt

models = ['random forest', 'XGBOOST', 'Bagging Regressor', 'Adaboost', 'Decision Tree', 'K neighbours','Guassian']
scores = [random_accuracy , xgboost_accuracy, bagging_accuracy,adaboost_accuracy,dt_accuracy,kneighbor_accuracy,gauss_accuracy]


plt.figure(figsize=(12, 8))
plt.plot(models, scores, color='blue')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Model Scores')

plt.show()

# %% [markdown]
# We can save the model

# %%
joblib.dump(random_fr, "creditcard.sav")
# Out:
# ['creditcard.sav']

# %%
# export the cleaned csv
df.to_csv("creditcard_cleaned.csv")
